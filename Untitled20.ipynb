# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavshinde2904-bot/Assignment-1/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a list
my_list = [10, 20, 30, 40, 50]

# Check element presence
num = 30

if num in my_list:
    print(num, "is present in the list")
else:
    print(num, "is not present in the list")

# Using not in
if 60 not in my_list:
    print("60 is not present in the list")
# Out:
# 30 is present in the list
# 60 is not present in the list
