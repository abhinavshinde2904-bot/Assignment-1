# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavshinde2904-bot/Assignment-1/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Take string input from user
string = input("7")

# Check length condition
if len(string) < 2:
    print("7")
else:
    result = string[:2] + string[-2:]
    print("New string is:", result)
# Out:
# 75
# 7
