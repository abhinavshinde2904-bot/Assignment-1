# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavshinde2904-bot/Assignment-1/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]

# Concatenation
result = list1 + list2
print("Concatenation:", result)

# Repetition
print("Repetition:", list1 * 2)

# Length
print("Length of list1:", len(list1))

# Maximum
print("Maximum value:", max(result))

# Minimum
print("Minimum value:", min(result))
# Out:
# Concatenation: [1, 2, 3, 4, 5, 6]
# Repetition: [1, 2, 3, 1, 2, 3]
# Length of list1: 3
# Maximum value: 6
# Minimum value: 1
