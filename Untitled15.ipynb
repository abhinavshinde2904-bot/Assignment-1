# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavshinde2904-bot/Assignment-1/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
string = input("Enter a string: ")

result = ""

for i in range(len(string)):
    if i % 2 == 0:
        result += string[i]

print("Result:", result)
# Out:
# Enter a string: 6
# Result: 6
