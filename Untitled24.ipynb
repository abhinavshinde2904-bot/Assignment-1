# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavshinde2904-bot/Assignment-1/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Integer data type
a = 10
b = 25

print("Value of a:", a)
print("Value of b:", b)
print("Type of a:", type(a))

# Float data type
x = 10.5
y = 3.14

print("Value of x:", x)
print("Value of y:", y)
print("Type of x:", type(x))

# String data type
name = "Abhinav"

print("Name:", name)
print("Type of name:", type(name))

# Boolean data type
is_student = True

print("Value:", is_student)
print("Type:", type(is_student))

# List data type
numbers = [10, 20, 30, 40]

print("List:", numbers)
print("First element:", numbers[0])
print("Type:", type(numbers))

# Tuple data type
colors = ("red", "green", "blue")

print("Tuple:", colors)
print("First element:", colors[0])
print("Type:", type(colors))

# Dictionary data type
student = {
    "name": "Abhinav",
    "age": 18,
    "branch": "CSE"
}

print("Dictionary:", student)
print("Student name:", student["name"])
print("Type:", type(student))
# Out:
# Value of a: 10
# Value of b: 25
# Type of a: <class 'int'>
# Value of x: 10.5
# Value of y: 3.14
# Type of x: <class 'float'>
# Name: Abhinav
# Type of name: <class 'str'>
# Value: True
# Type: <class 'bool'>
# List: [10, 20, 30, 40]
# First element: 10
# Type: <class 'list'>
# Tuple: ('red', 'green', 'blue')
# First element: red
# Type: <class 'tuple'>
# Dictionary: {'name': 'Abhinav', 'age': 18, 'branch': 'CSE'}
# Student name: Abhinav
# Type: <class 'dict'>
