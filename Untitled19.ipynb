# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavshinde2904-bot/Assignment-1/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Take two strings as input
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

# Concatenate strings
result = str1 + str2
print("Concatenated string is:", result)
# Out:
# Enter first string: 7
# Enter second string: 7
# Concatenated string is: 77
