# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavshinde2904-bot/Assignment-1/blob/main/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 20
c = a + b
print("Addition =", c)


a = 100
name = "abhinav"
print("Type of a:", type(a))
print("Type of name:", type(name))


a = 10
b = float(a)
print("Value of a:", a)
print("After type casting to float:", b)
print("Type of b:", type(b))


a = 10
b = 5
print(a > 5 and b > 2)
print(a > 5 or b > 10)
print(not(a > 5))
# Out:
# Addition = 30
# Type of a: <class 'int'>
# Type of name: <class 'str'>
# Value of a: 10
# After type casting to float: 10.0
# Type of b: <class 'float'>
# True
# True
# False
